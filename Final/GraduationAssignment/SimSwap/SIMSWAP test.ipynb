# %%
# !unzip /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints.zip  -d /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/
# Out:
# Archive:  /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints.zip
#    creating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/
#   inflating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/iter.txt
#   inflating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/latest_net_D1.pth
#   inflating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/latest_net_D2.pth
#   inflating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/latest_net_G.pth
#   inflating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/loss_log.txt
#   inflating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/opt.txt
#    creating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/web/
#    creating: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people/web/images/

# %%
# !mv /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/people /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints

# %%
# !python /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/test_one_image.py \
--checkpoints_dir /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints \
--isTrain false \
--name people \
--Arc_path /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/arcface_model/arcface_checkpoint.tar \
--pic_a_path /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/crop_224/6.jpg \
--pic_b_path /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/crop_224/ds.jpg \
--output_path /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/output/
# Out:
# ------------ Options -------------
# Arc_path: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/arcface_model/arcface_checkpoint.tar
# aspect_ratio: 1.0
# batchSize: 8
# checkpoints_dir: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./datasets/cityscapes/
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 50
# id_thres: 0.03
# image_size: 224
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# latent_size: 512
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# multisepcific_dir: ./demo_file/multispecific
# nThreads: 2
# n_blocks_global: 6
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 3
# n_local_enhancers: 1
# name: people
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# ...

# %%
# !python /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/test_one_image.py \
--checkpoints_dir /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints \
--isTrain false \
--name people \
--Arc_path /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/arcface_model/arcface_checkpoint.tar \
--pic_a_path /content/drive/MyDrive/ColabNotebooks/Final/Final_ing_data_test/ADA-Results/data10/aligned_croppedImage0_proj.png \
--pic_b_path /content/drive/MyDrive/ColabNotebooks/Final/Final_ing_data_test/RetinaFace-Cropimgs/data10/croppedImage0.png \
--output_path /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/output/
# Out:
# ------------ Options -------------
# Arc_path: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/arcface_model/arcface_checkpoint.tar
# aspect_ratio: 1.0
# batchSize: 8
# checkpoints_dir: /content/drive/MyDrive/ColabNotebooks/Final/SimSwap/checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./datasets/cityscapes/
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 50
# id_thres: 0.03
# image_size: 224
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# latent_size: 512
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# multisepcific_dir: ./demo_file/multispecific
# nThreads: 2
# n_blocks_global: 6
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 3
# n_local_enhancers: 1
# name: people
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# ...
