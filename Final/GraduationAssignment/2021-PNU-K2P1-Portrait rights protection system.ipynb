# %% [markdown]
# ### 0. Bring and install the necessary libraries.

# %%
# !pip install requests
# !pip install Pillow
# !pip install tqdm
# !pip install dlib
# !pip install -U retinaface_pytorch
# !pip install ninja
# !pip install insightface==0.2.1 onnxruntime moviepy
# !pip install streamlit
# !pip install pyngrok
# !pip install "opencv-python-headless<4.3"

# %% [markdown]
# ### 1. Restart the Google Colab runtime and then run the following code. And allow drive mount permission.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. Sign up [ngrok](https://ngrok.com/) and get your authtoken. Then write and execute your authtoken after '!ngrok'.

# %%
# !ngrok authtoken write_your_authtoken_here
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# ### 3. Execute the below codes. And click the link of 'p_url'.

# %%
from pyngrok import ngrok

# %%
# !streamlit run /content/drive/MyDrive/ColabNotebooks/Final/GraduationAssignment/streamlit.py&>/dev/null&

# %%
p_url = ngrok.connect(addr='8501')

# %%
p_url
# Out:
# <NgrokTunnel: "http://66bd-34-85-206-138.ngrok.io" -> "http://localhost:8501">

# %% [markdown]
# ### 4. After using the project, you have to kill steamlit and ngrok. In the list of '!ps', find the PID of streamlit and kill the PID.

# %%
# !ps
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       8 ?        00:00:03 node
#      19 ?        00:00:00 tail
#      30 ?        00:00:04 python3 <defunct>
#      31 ?        00:00:00 colab-fileshim.
#      56 ?        00:00:02 jupyter-noteboo
#      57 ?        00:00:00 dap_multiplexer
#     280 ?        00:00:02 python3
#     303 ?        00:00:00 python3
#     318 ?        00:00:09 node
#     352 ?        00:00:00 bash
#     353 ?        00:00:00 drive
#     354 ?        00:00:00 grep
#     416 ?        00:00:01 drive
#     492 ?        00:00:00 bash
#     493 ?        00:00:00 directoryprefet
#     494 ?        00:00:00 tail
#     495 ?        00:00:00 python3
#     521 ?        00:00:04 streamlit
#     531 ?        00:00:00 ngrok
#     552 ?        00:00:00 ps

# %%
# !kill 521

# %%
# !ps
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       8 ?        00:00:03 node
#      19 ?        00:00:00 tail
#      30 ?        00:00:04 python3 <defunct>
#      31 ?        00:00:00 colab-fileshim.
#      56 ?        00:00:02 jupyter-noteboo
#      57 ?        00:00:00 dap_multiplexer
#     280 ?        00:00:02 python3
#     303 ?        00:00:00 python3
#     318 ?        00:00:10 node
#     352 ?        00:00:00 bash
#     353 ?        00:00:00 drive
#     354 ?        00:00:00 grep
#     416 ?        00:00:01 drive
#     492 ?        00:00:00 bash
#     493 ?        00:00:00 directoryprefet
#     494 ?        00:00:00 tail
#     495 ?        00:00:00 python3
#     531 ?        00:00:00 ngrok
#     566 ?        00:00:00 ps

# %% [markdown]
# ### 5. Also kill ngrok.

# %%
ngrok.kill()

# %%
# !ps
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       8 ?        00:00:03 node
#      19 ?        00:00:00 tail
#      30 ?        00:00:04 python3 <defunct>
#      31 ?        00:00:00 colab-fileshim.
#      56 ?        00:00:02 jupyter-noteboo
#      57 ?        00:00:00 dap_multiplexer
#     280 ?        00:00:02 python3
#     303 ?        00:00:00 python3
#     318 ?        00:00:10 node
#     352 ?        00:00:00 bash
#     353 ?        00:00:00 drive
#     354 ?        00:00:00 grep
#     416 ?        00:00:01 drive
#     492 ?        00:00:00 bash
#     493 ?        00:00:00 directoryprefet
#     494 ?        00:00:00 tail
#     495 ?        00:00:00 python3
#     569 ?        00:00:00 ps
